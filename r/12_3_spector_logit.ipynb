# %% [markdown]
# # Logit model

# %%
# CSVファイルの読み込み
data <- read.csv("../data/12-Spector.csv")

# %%
# データを確認（先頭5件）
head(data, 5)
# Out:
#   OBS GPA  TUCE PSI GRADE LETTER
# 1 1   2.66 20   0   0     C
# 2 2   2.89 22   0   0     B
# 3 3   3.28 24   0   0     B
# 4 4   2.92 12   0   0     B
# 5 5   4.00 21   0   1     A

# %%
# Logit回帰モデル
fit <- glm(GRADE ~ GPA + TUCE + PSI, family = binomial(link = "logit"), data = data)

# %%
# 結果の出力
summary(fit)
# Out:
# Call:
# glm(formula = GRADE ~ GPA + TUCE + PSI, family = binomial(link = "logit"),
#     data = data)
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept) -13.02135    4.93127  -2.641  0.00828 **
# GPA           2.82611    1.26293   2.238  0.02524 *
# TUCE          0.09516    0.14155   0.672  0.50143
# PSI           2.37869    1.06456   2.234  0.02545 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 41.183  on 31  degrees of freedom
# Residual deviance: 25.779  on 28  degrees of freedom
# AIC: 33.779
#
# Number of Fisher Scoring iterations: 5
