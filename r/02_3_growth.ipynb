# %% [markdown]
# # Log-Linear models
# 価格と需要の関係を、療法の変数を対数変換して回帰分析します。

# %%
# CSVファイルの読み込み
data <- read.csv("../data/2-growth.csv")

# %%
# データを確認（先頭5件）
head(data, 5)
# Out:
#   t    Y
# 1 1995 123
# 2 1996 145
# 3 1997 150
# 4 1998 144
# 5 1999 147

# %%
# 対数変換
data$lnY <- log(data$Y)

# %%
# 回帰分析
model <- lm(lnY ~ t, data = data)

# %%
# 結果の表示
summary(model)
# Out:
# Call:
# lm(formula = lnY ~ t, data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.088398 -0.018116  0.001593  0.024130  0.054249
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -50.76346    8.16020  -6.221 0.000155 ***
# t             0.02790    0.00408   6.839 7.57e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.04279 on 9 degrees of freedom
# Multiple R-squared:  0.8386,	Adjusted R-squared:  0.8207
# F-statistic: 46.77 on 1 and 9 DF,  p-value: 7.57e-05
