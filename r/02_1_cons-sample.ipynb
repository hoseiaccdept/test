# %% [markdown]
# # Ordinary least squares estimation
# Income(X)とConsumption(Y)の関係を単回帰モデルで分析

# %%
# CSVファイルの読み込み
data <- read.csv("../data/2-cons-sample.csv")

# %%
# データを確認（先頭5件）
head(data, 5)
# Out:
#   No Consumption Income
# 1 1  39          50
# 2 2  42          50
# 3 3  47          60
# 4 4  53          70
# 5 5  55          70

# %%
# 回帰分析
model <- lm(Consumption ~ Income, data = data)

# %%
# 結果の表示
summary(model)
# Out:
# Call:
# lm(formula = Consumption ~ Income, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.8635 -1.2958 -0.3304  1.3699  5.0039
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.46004    2.54758   0.181    0.859
# Income       0.79337    0.02937  27.015 5.09e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.576 on 18 degrees of freedom
# Multiple R-squared:  0.9759,	Adjusted R-squared:  0.9746
# F-statistic: 729.8 on 1 and 18 DF,  p-value: 5.086e-16
