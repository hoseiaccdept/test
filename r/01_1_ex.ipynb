# %% [markdown]
# # t検定
#
# t検定: Processの平均が224と異なるかを検定

# %%
# CSVファイルの読み込み
data <- read.csv("../data/1-Ex 1-4.csv")

# %%
# データを確認（先頭5件）
head(data, 5)
# Out:
#   Process
# 1 223
# 2 221
# 3 224
# 4 225
# 5 221

# %%
# t検定
t_result <- t.test(data$Process, mu = 224)

# %%
# 結果の表示
t_result
# Out:
# 	One Sample t-test
#
# data:  data$Process
# t = 1.9186, df = 55, p-value = 0.06023
# alternative hypothesis: true mean is not equal to 224
# 95 percent confidence interval:
#  223.8768 229.6589
# sample estimates:
# mean of x
#  226.7679
