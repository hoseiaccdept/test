# %% [markdown]
# # t-test
# Processの平均が224と異なるかをt検定する

# %%
# %%capture
import stata_setup
stata_setup.config("C:\Program Files\StataNow19", "mp")

# %%
# %%stata
# * # CSVファイルの読み込み
# import delimited "../data/1-Ex 1-4.csv", clear
# Out:
# . * # CSVファイルの読み込み
# . import delimited "../data/1-Ex 1-4.csv", clear
# (encoding automatically selected: ISO-8859-2)
# (1 var, 56 obs)
#
# .

# %%
# %%stata
# * # データを確認（先頭5件）
# list in 1/5
# Out:
# . * # データを確認（先頭5件）
# . list in 1/5
#
#      +---------+
#      | process |
#      |---------|
#   1. |     223 |
#   2. |     221 |
#   3. |     224 |
#   4. |     225 |
#   5. |     221 |
#      +---------+
#
# .

# %%
# %%stata
# * # t検定
# ttest process == 224
# Out:
# . * # t検定(Processの平均が224と異なるかを検定)
# . ttest process == 224
#
# One-sample t test
# ------------------------------------------------------------------------------
# Variable |     Obs        Mean    Std. err.   Std. dev.   [95% conf. interval]
# ---------+--------------------------------------------------------------------
#  process |      56    226.7679    1.442624    10.79561    223.8768    229.6589
# ------------------------------------------------------------------------------
#     mean = mean(process)                                          t =   1.9186
# H0: mean = 224                                   Degrees of freedom =       55
#
#    Ha: mean < 224               Ha: mean != 224               Ha: mean > 224
#  Pr(T < t) = 0.9699         Pr(|T| > |t|) = 0.0602          Pr(T > t) = 0.0301
#
# .
