# %% [markdown]
# # Dummy variable Regression
# 消費を目的変数として、世帯主が男性か女性か（ダミー変数）と、所得（数量変数）の両方を説明変数とする回帰分析

# %%
# %%capture
import stata_setup
stata_setup.config("C:\Program Files\StataNow19", "mp")

# %%
# %%stata
# * # CSVファイルの読み込み
# import delimited "../data/4-dummy.csv", clear
# Out:
# . * # CSVファイルの読み込み
# . import delimited "../data/4-dummy.csv", clear
# (encoding automatically selected: ISO-8859-9)
# (4 vars, 20 obs)
#
# .

# %%
# %%stata
# * # データを確認（先頭5件）
# list in 1/5
# Out:
# . * # データを確認（先頭5件）
# . list in 1/5
#
#      +-----------------------------+
#      |    y      x   male   gender |
#      |-----------------------------|
#   1. | 1280   1800      1     male |
#   2. | 1380   1950      1     male |
#   3. | 1260   1790      0   female |
#   4. | 1090   1660      0   female |
#   5. | 1120   1520      0   female |
#      +-----------------------------+
#
# .

# %%
# %%stata
# * # モデル1: ダミー変数のみ
# regress y male
# Out:
# . * # モデル1: ダミー変数のみ
# . regress y male
#
#       Source |       SS           df       MS      Number of obs   =        20
# -------------+----------------------------------   F(1, 18)        =     14.16
#        Model |  385564.091         1  385564.091   Prob > F        =    0.0014
#     Residual |  490090.909        18  27227.2727   R-squared       =    0.4403
# -------------+----------------------------------   Adj R-squared   =    0.4092
#        Total |      875655        19  46087.1053   Root MSE        =    165.01
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#         male |   279.0909   74.16508     3.76   0.001     123.2759     434.906
#        _cons |       1190    55.0023    21.64   0.000     1074.444    1305.556
# ...

# %%
# %%stata
# * # モデル2
# regress y male x
# Out:
# . * # モデル2
# . regress y male x
#
#       Source |       SS           df       MS      Number of obs   =        20
# -------------+----------------------------------   F(2, 17)        =     26.26
#        Model |  661506.322         2  330753.161   Prob > F        =    0.0000
#     Residual |  214148.678        17  12596.9811   R-squared       =    0.7554
# -------------+----------------------------------   Adj R-squared   =    0.7267
#        Total |      875655        19  46087.1053   Root MSE        =    112.24
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#         male |   15.89432   75.54592     0.21   0.836    -143.4936    175.2823
#            x |   .4586598   .0979975     4.68   0.000     .2519032    .6654163
# ...
