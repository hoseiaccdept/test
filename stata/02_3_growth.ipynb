# %% [markdown]
# # Log-Linear models
# 年次データYの自然対数を取って、時間tに対する成長率を推定

# %%
# %%capture
import stata_setup
stata_setup.config("C:\Program Files\StataNow19", "mp")

# %%
# %%stata
# * # CSVファイルの読み込み
# import delimited "../data/2-growth.csv", clear
# Out:
# . * # CSVファイルの読み込み
# . import delimited "../data/2-growth.csv", clear
# (encoding automatically selected: ISO-8859-1)
# (2 vars, 11 obs)
#
# .

# %%
# %%stata
# * # データを確認（先頭5件）
# list in 1/5
# Out:
# . * # データを確認（先頭5件）
# . list in 1/5
#
#      +------------+
#      |    t     y |
#      |------------|
#   1. | 1995   123 |
#   2. | 1996   145 |
#   3. | 1997   150 |
#   4. | 1998   144 |
#   5. | 1999   147 |
#      +------------+
#
# .

# %%
# %%stata
# * # 対数変換
# gen lny = log(y)
# Out:
# . * # 対数変換
# . gen lny = log(y)
#
# .

# %%
# %%stata
# * # 回帰分析
# regress lny t
# Out:
# . * # 回帰分析
# . regress lny t
#
#       Source |       SS           df       MS      Number of obs   =        11
# -------------+----------------------------------   F(1, 9)         =     46.77
#        Model |  .085635996         1  .085635996   Prob > F        =    0.0001
#     Residual |  .016480701         9  .001831189   R-squared       =    0.8386
# -------------+----------------------------------   Adj R-squared   =    0.8207
#        Total |  .102116697        10   .01021167   Root MSE        =    .04279
#
# ------------------------------------------------------------------------------
#          lny | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#            t |   .0279018   .0040801     6.84   0.000      .018672    .0371316
#        _cons |  -50.76346     8.1602    -6.22   0.000    -69.22311    -32.3038
# ...
