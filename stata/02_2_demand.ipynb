# %% [markdown]
# # Log-log linear models
# 価格と需要の関係を、両方の変数を対数変換して回帰分析

# %%
# %%capture
import stata_setup
stata_setup.config("C:\Program Files\StataNow19", "mp")

# %%
# %%stata
# * # CSVファイルの読み込み
# import delimited "../data/2-demand.csv", clear
# Out:
# . * # CSVファイルの読み込み
# . import delimited "../data/2-demand.csv", clear
# (encoding automatically selected: ISO-8859-2)
# (3 vars, 10 obs)
#
# .

# %%
# %%stata
# * # データを確認（先頭5件）
# list in 1/5
# Out:
# . * # データを確認（先頭5件）
# . list in 1/5
#
#      +---------------+
#      | no     p    q |
#      |---------------|
#   1. |  1   100   73 |
#   2. |  2   105   71 |
#   3. |  3   106   70 |
#   4. |  4   109   62 |
#   5. |  5   110   59 |
#      +---------------+
#
# .

# %%
# %%stata
# * # 対数変換
# gen lnp = log(p)
# gen lnq = log(q)
# Out:
# . * # 対数変換
# . gen lnp = log(p)
#
# . gen lnq = log(q)
#
# .

# %%
# %%stata
# * # 回帰分析
# regress lnq lnp
# Out:
# . * # 回帰分析
# . regress lnq lnp
#
#       Source |       SS           df       MS      Number of obs   =        10
# -------------+----------------------------------   F(1, 8)         =      6.59
#        Model |  .024205484         1  .024205484   Prob > F        =    0.0333
#     Residual |  .029404034         8  .003675504   R-squared       =    0.4515
# -------------+----------------------------------   Adj R-squared   =    0.3830
#        Total |  .053609518         9  .005956613   Root MSE        =    .06063
# ------------------------------------------------------------------------------
#          lnq | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#          lnp |  -.7832847   .3052258    -2.57   0.033    -1.487137   -.0794328
#        _cons |   7.868182   1.440553     5.46   0.001     4.546259     11.1901
# ...
