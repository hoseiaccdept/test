# %% [markdown]
# # Multicollinearity

# %%
# %%capture
import stata_setup
stata_setup.config("C:\Program Files\StataNow19", "mp")

# %%
# %%stata
# * # CSVファイルの読み込み
# import delimited "../data/5-Multicollinearity.csv", clear
# Out:
# . * # CSVファイルの読み込み
# . import delimited "../data/5-Multicollinearity.csv", clear
# (encoding automatically selected: UTF-8)
# (4 vars, 10 obs)
#
# .

# %%
# %%stata
# * # データを確認（先頭5件）
# list in 1/5
# Out:
# . * # データを確認（先頭5件）
# . list in 1/5
#
#      +--------------------+
#      |  y   x1    x2   x3 |
#      |--------------------|
#   1. | 10    1     1    1 |
#   2. | 13    2     2    2 |
#   3. | 15    3   3.5    3 |
#   4. | 16    4     4    4 |
#   5. | 18    5     5    5 |
#      +--------------------+
#
# .

# %%
# %%stata
# regress y x1
# Out:
#       Source |       SS           df       MS      Number of obs   =        10
# -------------+----------------------------------   F(1, 8)         =     26.43
#        Model |  61.1030303         1  61.1030303   Prob > F        =    0.0009
#     Residual |  18.4969697         8  2.31212121   R-squared       =    0.7676
# -------------+----------------------------------   Adj R-squared   =    0.7386
#        Total |        79.6         9  8.84444444   Root MSE        =    1.5206
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#           x1 |   .8606061   .1674088     5.14   0.001     .4745606    1.246651
#        _cons |   11.46667   1.038744    11.04   0.000     9.071318    13.86202
# ------------------------------------------------------------------------------

# %%
# %%stata
# regress y x1 x2
# Out:
#       Source |       SS           df       MS      Number of obs   =        10
# -------------+----------------------------------   F(2, 7)         =     12.51
#        Model |  62.2014706         2  31.1007353   Prob > F        =    0.0049
#     Residual |  17.3985294         7   2.4855042   R-squared       =    0.7814
# -------------+----------------------------------   Adj R-squared   =    0.7190
#        Total |        79.6         9  8.84444444   Root MSE        =    1.5765
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#           x1 |  -1.413235   3.424819    -0.41   0.692    -9.511646    6.685175
#           x2 |   2.308824    3.47304     0.66   0.527    -5.903611    10.52126
#        _cons |   11.15882   1.172321     9.52   0.000     8.386724    13.93092
# ...
